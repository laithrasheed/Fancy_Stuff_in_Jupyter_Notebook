# %%
# !pip install jupyterthemes

# %%
# the output is a list that shows availabe themes

# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# to restore to the origional theme
# !jt -r
# Out:
# Reset css and font defaults in:
# C:\Users\USER\.jupyter\custom &
# C:\Users\USER\AppData\Roaming\jupyter\nbextensions

# %% [markdown]
# Enable the toolbar```: !jt -t theme name -T```
#
# Enable the filename and logo: !jt -t ```theme name -N```
#
# Enable the kernel logo: !jt -t ```theme name -kl```
#
# To change the theme and enable the toolbar, filename, logo, kernel logo in same command line statement:
# ```!jt -t theme name -T -N -kl```

# %%
# this is my facorite theme because of the following Markdown cell
# !jt -t chesterish -T -N -kl

# %% [markdown]
# Response #2:
#
#
# This code defines a class called `DisjointForests` which implements a union-find data structure with rank compression.
#
# Here's a line-by-line explanation of the code:
#
# ```python
# class DisjointForests:
#     def __init__(self, n):
#         assert n >= 1, ' Empty disjoint forest is disallowed'
#         self.n = n
#         self.parents = [None]*n
#         self.rank = [None]*n
# ```
#
# - `class DisjointForests:`: This line defines a new class called `DisjointForests`.
#
# - `def __init__(self, n):`: This line defines the initialization method for the `DisjointForests` class. It takes one argument `n`, which represents the number of elements in the disjoint forest.
#
# - `assert n >= 1, ' Empty disjoint forest is disallowed'`: This line checks that the input `n` is greater than or equal to 1. If it is not, it raises an `AssertionError` with the message `'Empty disjoint forest is disallowed'`.
#
# - `self.n = n`: This line sets the `n` attribute of the `DisjointForests` instance to the input `n`.
#
# - `self.parents = [None]*n`: This line initializes the `parents` attribute of the `DisjointForests` instance to a list of length `n` filled with `None` values. Each element in the list will eventually represent the parent of a particular element in the disjoint forest.
#
# - `self.rank = [None]*n`: This line initializes the `rank` attribute of the `DisjointForests` instance to a list of length `n` filled with `None` values. Each element in the list will eventually represent the rank of a particular element in the disjoint forest.

# %% [markdown]
# ## here is a screenshot for the theme:
# ![image.png](attachment:image.png)
